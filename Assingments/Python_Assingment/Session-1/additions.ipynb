# %%
a=25
b=20
c=a+b
print("addition of numbers is:",c)
# Out:
# addition of numbers is: 45

# %%
a=25
b=20
c=a-b
print("subtraction of numbers is:",c)
# Out:
# subtraction of numbers is: 5

# %%
a=25
b=20
c=a*b
print("multiplication of numbers is:",c)
# Out:
# multiplication of numbers is: 500

# %%
a=25
b=20
c=a/b
print("division of numbers is:",c)
# Out:
# division of numbers is: 1.25

# %%
a=25
b=20
c=a%b
print("modulas of numbers is:",c)
# Out:
# modulas of numbers is: 5

# %%
a=2
b=4
c=a**b
print("exponencial of numbers is:",c)
# Out:
# exponencial of numbers is: 16
