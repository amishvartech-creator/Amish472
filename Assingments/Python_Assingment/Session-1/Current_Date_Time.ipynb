# %%
# current date and time print
import datetime
print(datetime.datetime.now())
# Out:
# 2026-08-15 14:45:45.226647

# %%
# get the current year
current_year=datetime.datetime.now().year
print(current_year)
# Out:
# 2026
